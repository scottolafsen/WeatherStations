# %%
import pandas as pd
import requests 
import json
# import matplotlib

# %%
response = requests.get("https://api.synopticdata.com/v2/stations/latest?stid=CCD,%20CLK,%20CDYBK,%20CDSUT,%20C99,%20PCPCN,%20PCH,%20PCPD,%20THCU1,%20PCSL,%20PCT,%20PCZ,%20PCS,%20SNC,%20PCB,%20EMPUT,%20SNV,%20DVO,%20MBY,%20DVB,%20DVG,%20PKCU1,%20BRC,%20SOLSM,%20BRW,%20SOL,%20SOLAP,%20SOLBS,%20SOLMB,%20SOLHP,%20REY,%20UTSTR,%20UTTPD,%20UTCDF,%20SPC,%20MLDU1,%20CLN,%20ALT,%20IFF,%20AMB,%20ATB,%20AGD,%20ATH20,%20SBDU1,%20UTPLC,%20UTWLC,%20ELBUT&status=active&vars=,pressure&units=temp|F,speed|mph,pres|mb,height|ft,precip|in,alti|inhg&token=5f4bddebeaba4e6892eade4aa033e41b")

# %%
response2 = requests.get("https://api.synopticdata.com/v2/stations/timeseries?stid=CLN&recent=10080&status=active&vars=,pressure&units=temp|F,speed|mph,pres|mb,height|ft,precip|in,alti|inhg&token=5f4bddebeaba4e6892eade4aa033e41b")

# %%
# data = response.json()

dataTs = response2.json()
print(dataTs)
# Out:
# {'UNITS': {'snow_depth': 'Inches', 'snow_interval': 'Inches', 'elevation': 'ft', 'air_temp': 'Fahrenheit', 'precip_accum_one_hour': 'Inches', 'position': 'ft'}, 'QC_SUMMARY': {'QC_TESTS_APPLIED': ['sl_range_check'], 'TOTAL_OBSERVATIONS_FLAGGED': 0.0, 'PERCENT_OF_TOTAL_OBSERVATIONS_FLAGGED': 0.0}, 'STATION': [{'STATUS': 'ACTIVE', 'MNET_ID': '6', 'PERIOD_OF_RECORD': {'start': '1997-01-01T00:00:00Z', 'end': '2020-02-11T23:00:00Z'}, 'ELEVATION': '9662', 'NAME': 'ALTA - COLLINS', 'STID': 'CLN', 'SENSOR_VARIABLES': {'precip_accum_one_hour': {'precip_accum_one_hour_set_1': {}}, 'date_time': {'date_time': {}}, 'snow_interval': {'snow_interval_set_1': {}}, 'air_temp': {'air_temp_set_1': {}}, 'snow_depth': {'snow_depth_set_1': {}}}, 'ELEV_DEM': '9629.3', 'LONGITUDE': '-111.6383', 'STATE': 'UT', 'OBSERVATIONS': {'date_time': ['2020-02-09T18:00:00Z', '2020-02-09T19:00:00Z', '2020-02-09T20:00:00Z', '2020-02-09T21:00:00Z', '2020-02-09T22:00:00Z', '2020-02-09T23:00:00Z', '2020-02-10T00:00:00Z', '20
# ...

# %%
# data2 = data['STATION']
dataTimeSeries = dataTs['STATION']

# %%
# data2
p = dataTimeSeries[0]['OBSERVATIONS']

# %%
# df = pd.DataFrame(data2)
# df = pd.DataFrame(dataTimeSeries)
# df['OBSERVATIONS']
df = pd.DataFrame(p)
df
# Out:
#                 date_time  snow_interval_set_1  air_temp_set_1  \
# 0    2020-02-09T18:00:00Z                  0.0           12.99
# 1    2020-02-09T19:00:00Z                  0.0           14.00
# 2    2020-02-09T20:00:00Z                  0.0           16.00
# 3    2020-02-09T21:00:00Z                  0.0           19.99
# 4    2020-02-09T22:00:00Z                  0.0           16.00
# 5    2020-02-09T23:00:00Z                  0.0           14.00
# 6    2020-02-10T00:00:00Z                  0.0           12.00
# 7    2020-02-10T01:00:00Z                  0.0            8.01
# 8    2020-02-10T02:00:00Z                  0.0            6.01
# 9    2020-02-10T03:00:00Z                  0.0            7.00
# 10   2020-02-10T04:00:00Z                  0.0            6.01
# 11   2020-02-10T05:00:00Z                  0.0            3.99
# 12   2020-02-10T06:00:00Z                  0.0            5.00
# 13   2020-02-10T07:00:00Z                  0.0            3.99
# ...

# %%
type(df.date_time[0])
# Out:
# str

# %%
df.to_csv(r'C:\Users\Scott\Desktop\python\csv\wxTimeSeries.csv')
